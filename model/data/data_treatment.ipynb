# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
pl_base_stats = pd.read_csv('./data/player_stats_1998_2022.csv')
pl_adv_stats = pd.read_csv('./data/player_adv_stats_1998_2022.csv')
team_stats = pd.read_csv('./data/all_teams_stats_df_1998_2022.csv')

# %% [markdown]
# Base stats.

# %%
pl_base_stats
# Out:
#        PLAYER_ID      PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION  \
# 0            920       A.C. Green     A.C.  1610612742               DAL
# 1            243      Aaron McKie    Aaron  1610612755               PHI
# 2           1425   Aaron Williams    Aaron  1610612760               SEA
# 3            228       Adam Keefe     Adam  1610612762               UTA
# 4           1502     Adonal Foyle   Adonal  1610612744               GSW
# ...          ...              ...      ...         ...               ...
# 11961    1628380     Zach Collins     Zach  1610612759               SAS
# 11962     203897      Zach LaVine     Zach  1610612741               CHI
# 11963    1630192       Zeke Nnaji     Zeke  1610612743               DEN
# 11964    1630533  Ziaire Williams   Ziaire  1610612763               MEM
# 11965    1629627  Zion Williamson     Zion  1610612740               NOP
#
#         AGE  GP   W   L  W_PCT   MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# ...

# %%
pl_base_stats = pl_base_stats.drop(columns=pl_base_stats.filter(like='_RANK').columns)

# %%
pl_base_stats
# Out:
#        PLAYER_ID      PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION  \
# 0            920       A.C. Green     A.C.  1610612742               DAL
# 1            243      Aaron McKie    Aaron  1610612755               PHI
# 2           1425   Aaron Williams    Aaron  1610612760               SEA
# 3            228       Adam Keefe     Adam  1610612762               UTA
# 4           1502     Adonal Foyle   Adonal  1610612744               GSW
# ...          ...              ...      ...         ...               ...
# 11961    1628380     Zach Collins     Zach  1610612759               SAS
# 11962     203897      Zach LaVine     Zach  1610612741               CHI
# 11963    1630192       Zeke Nnaji     Zeke  1610612743               DEN
# 11964    1630533  Ziaire Williams   Ziaire  1610612763               MEM
# 11965    1629627  Zion Williamson     Zion  1610612740               NOP
#
#         AGE  GP   W   L  W_PCT   MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# ...

# %%
pl_base_stats['PK'] = pl_base_stats['PLAYER_ID'].astype(str) + '_' + pl_base_stats['SEASON']

# %% [markdown]
# Advanced stats.

# %%
pl_adv_stats
# Out:
#        PLAYER_ID      PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION  \
# 0            920       A.C. Green     A.C.  1610612742               DAL
# 1            243      Aaron McKie    Aaron  1610612755               PHI
# 2           1425   Aaron Williams    Aaron  1610612760               SEA
# 3            228       Adam Keefe     Adam  1610612762               UTA
# 4           1502     Adonal Foyle   Adonal  1610612744               GSW
# ...          ...              ...      ...         ...               ...
# 11961    1628380     Zach Collins     Zach  1610612759               SAS
# 11962     203897      Zach LaVine     Zach  1610612741               CHI
# 11963    1630192       Zeke Nnaji     Zeke  1610612743               DEN
# 11964    1630533  Ziaire Williams   Ziaire  1610612763               MEM
# 11965    1629627  Zion Williamson     Zion  1610612740               NOP
#
#         AGE  GP   W   L  W_PCT   MIN  E_OFF_RATING  OFF_RATING  \
# ...

# %%
pl_adv_stats = pl_adv_stats.drop(columns=pl_adv_stats.filter(like='_RANK').columns)

# %%
pl_adv_stats
# Out:
#        PLAYER_ID      PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION  \
# 0            920       A.C. Green     A.C.  1610612742               DAL
# 1            243      Aaron McKie    Aaron  1610612755               PHI
# 2           1425   Aaron Williams    Aaron  1610612760               SEA
# 3            228       Adam Keefe     Adam  1610612762               UTA
# 4           1502     Adonal Foyle   Adonal  1610612744               GSW
# ...          ...              ...      ...         ...               ...
# 11961    1628380     Zach Collins     Zach  1610612759               SAS
# 11962     203897      Zach LaVine     Zach  1610612741               CHI
# 11963    1630192       Zeke Nnaji     Zeke  1610612743               DEN
# 11964    1630533  Ziaire Williams   Ziaire  1610612763               MEM
# 11965    1629627  Zion Williamson     Zion  1610612740               NOP
#
#         AGE  GP   W   L  W_PCT   MIN  E_OFF_RATING  OFF_RATING  \
# ...

# %%
pl_adv_stats['PK'] = pl_adv_stats['PLAYER_ID'].astype(str) + '_' + pl_adv_stats['SEASON']

# %% [markdown]
# Concat base and advanced stats.

# %%
pl_stats = pl_base_stats.merge(pl_adv_stats, on='PK', how='left')

# %%
pl_stats
# Out:
#        PLAYER_ID_x    PLAYER_NAME_x NICKNAME_x   TEAM_ID_x  \
# 0              920       A.C. Green       A.C.  1610612742
# 1              243      Aaron McKie      Aaron  1610612755
# 2             1425   Aaron Williams      Aaron  1610612760
# 3              228       Adam Keefe       Adam  1610612762
# 4             1502     Adonal Foyle     Adonal  1610612744
# ...            ...              ...        ...         ...
# 11961      1628380     Zach Collins       Zach  1610612759
# 11962       203897      Zach LaVine       Zach  1610612741
# 11963      1630192       Zeke Nnaji       Zeke  1610612743
# 11964      1630533  Ziaire Williams     Ziaire  1610612763
# 11965      1629627  Zion Williamson       Zion  1610612740
#
#       TEAM_ABBREVIATION_x  AGE_x  GP_x  W_x  L_x  W_PCT_x  MIN_x  FGM_x  \
# 0                     DAL   35.0    50   19   31    0.380   18.5    2.2
# 1                     PHI   26.0    50   28   22    0.560   19.2    1.9
# ...

# %% [markdown]
# We eliminate the columns with "_y" as we already have that info.

# %%
pl_stats = pl_stats.drop(columns=pl_stats.filter(like='_y').columns)

# %%
pl_stats
# Out:
#        PLAYER_ID_x    PLAYER_NAME_x NICKNAME_x   TEAM_ID_x  \
# 0              920       A.C. Green       A.C.  1610612742
# 1              243      Aaron McKie      Aaron  1610612755
# 2             1425   Aaron Williams      Aaron  1610612760
# 3              228       Adam Keefe       Adam  1610612762
# 4             1502     Adonal Foyle     Adonal  1610612744
# ...            ...              ...        ...         ...
# 11961      1628380     Zach Collins       Zach  1610612759
# 11962       203897      Zach LaVine       Zach  1610612741
# 11963      1630192       Zeke Nnaji       Zeke  1610612743
# 11964      1630533  Ziaire Williams     Ziaire  1610612763
# 11965      1629627  Zion Williamson       Zion  1610612740
#
#       TEAM_ABBREVIATION_x  AGE_x  GP_x  W_x  L_x  W_PCT_x  MIN_x  FGM_x  \
# 0                     DAL   35.0    50   19   31    0.380   18.5    2.2
# 1                     PHI   26.0    50   28   22    0.560   19.2    1.9
# ...

# %% [markdown]
# We eliminate "_x" at the end of the columns (we've checked that this pattern it's only present as a suffix).

# %%
pl_stats.columns = pl_stats.columns.str.rstrip('_x')

# %%
pl_stats
# Out:
#        PLAYER_ID      PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION  \
# 0            920       A.C. Green     A.C.  1610612742               DAL
# 1            243      Aaron McKie    Aaron  1610612755               PHI
# 2           1425   Aaron Williams    Aaron  1610612760               SEA
# 3            228       Adam Keefe     Adam  1610612762               UTA
# 4           1502     Adonal Foyle   Adonal  1610612744               GSW
# ...          ...              ...      ...         ...               ...
# 11961    1628380     Zach Collins     Zach  1610612759               SAS
# 11962     203897      Zach LaVine     Zach  1610612741               CHI
# 11963    1630192       Zeke Nnaji     Zeke  1610612743               DEN
# 11964    1630533  Ziaire Williams   Ziaire  1610612763               MEM
# 11965    1629627  Zion Williamson     Zion  1610612740               NOP
#
#         AGE  GP   W   L  W_PCT   MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# ...

# %%
pl_stats.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# Team stats.

# %%
team_stats
# Out:
#         TEAM_ID  TEAM_CITY TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
# 0    1610612737    Atlanta     Hawks  1998-99  50    31      19    0.620
# 1    1610612737    Atlanta     Hawks  1999-00  82    28      54    0.341
# 2    1610612737    Atlanta     Hawks  2000-01  82    25      57    0.305
# 3    1610612737    Atlanta     Hawks  2001-02  82    33      49    0.402
# 4    1610612737    Atlanta     Hawks  2002-03  82    35      47    0.427
# ..          ...        ...       ...      ...  ..   ...     ...      ...
# 739  1610612766  Charlotte   Hornets  2018-19  82    39      43    0.476
# 740  1610612766  Charlotte   Hornets  2019-20  65    23      42    0.354
# 741  1610612766  Charlotte   Hornets  2020-21  72    33      39    0.458
# 742  1610612766  Charlotte   Hornets  2021-22  82    43      39    0.524
# 743  1610612766  Charlotte   Hornets  2022-23  82    27      55    0.329
#
#      CONF_RANK  DIV_RANK  PO_WINS  PO_LOSSES  CONF_COUNT  DIV_COUNT  \
# ...

# %% [markdown]
# We only need the team winning percentage and its position in the league. These are factors usually taken into account when evaluating a player for the MVP (if his team is capable of winning and how it's positioned in the league).

# %%
team_stats = team_stats[['TEAM_ID', 'YEAR', 'WIN_PCT', 'CONF_RANK', 'DIV_RANK']]

# %%
# team_stats

# %%
team_stats.isna().sum().sum()
# Out:
# 0

# %%
team_stats['PK_2'] = team_stats['TEAM_ID'].astype(str) + '_' + team_stats['YEAR']
# Out:
# C:\Users\dcast\AppData\Local\Temp\ipykernel_17836\2972468048.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_stats['PK_2'] = team_stats['TEAM_ID'].astype(str) + '_' + team_stats['YEAR']

# %%
# team_stats

# %%
team_stats.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# Concat pl_stats and team_stats.

# %%
pl_stats['PK_2'] = pl_stats['TEAM_ID'].astype(str) + '_' + pl_stats['SEASON']

# %%
pl_stats.isna().sum().sum()
# Out:
# 0

# %%
tot_stats = pl_stats.merge(team_stats, on='PK_2', how='left')

# %%
tot_stats.isna().sum().sum()
# Out:
# 0

# %%
tot_stats
# Out:
#        PLAYER_ID      PLAYER_NAME NICKNAME   TEAM_ID_x TEAM_ABBREVIATION  \
# 0            920       A.C. Green     A.C.  1610612742               DAL
# 1            243      Aaron McKie    Aaron  1610612755               PHI
# 2           1425   Aaron Williams    Aaron  1610612760               SEA
# 3            228       Adam Keefe     Adam  1610612762               UTA
# 4           1502     Adonal Foyle   Adonal  1610612744               GSW
# ...          ...              ...      ...         ...               ...
# 11961    1628380     Zach Collins     Zach  1610612759               SAS
# 11962     203897      Zach LaVine     Zach  1610612741               CHI
# 11963    1630192       Zeke Nnaji     Zeke  1610612743               DEN
# 11964    1630533  Ziaire Williams   Ziaire  1610612763               MEM
# 11965    1629627  Zion Williamson     Zion  1610612740               NOP
#
#         AGE  GP   W   L  W_PCT   MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# ...

# %%
tot_stats.drop(['TEAM_ID_y', 'YEAR'], axis=1, inplace=True)
tot_stats.rename(columns={'TEAM_ID_x': 'TEAM_ID'}, inplace=True)

# %%
# tot_stats

# %% [markdown]
# MVP votes data.

# %%
data_mvp = pd.read_csv('../mvp/mvp_data_1999_2023.csv')

# %%
data_mvp.head()
# Out:
#   Rank           Player  Age   Tm  First  Pts Won  Pts Max  Share   G    MP  \
# 0    1      Karl Malone   35  UTA   44.0    827.0     1180  0.701  49  37.4
# 1    2  Alonzo Mourning   28  MIA   36.0    773.0     1180  0.655  46  38.1
# 2    3       Tim Duncan   22  SAS   30.0    740.0     1180  0.627  50  39.3
# 3    4    Allen Iverson   23  PHI    5.0    319.0     1180  0.270  48  41.5
# 4    5       Jason Kidd   25  PHO    2.0    159.0     1180  0.135  50  41.2
#
#     PTS   TRB   AST  STL  BLK    FG%    3P%    FT%   WS  WS/48      Other  \
# 0  23.8   9.4   4.1  1.3  0.6  0.493  0.000  0.788  9.6  0.252  malonka01
# 1  20.1  11.0   1.6  0.7  3.9  0.511  0.000  0.652  7.9  0.216  mournal01
# 2  21.7  11.4   2.4  0.9  2.5  0.495  0.143  0.690  8.7  0.213  duncati01
# 3  26.8   4.9   4.6  2.3  0.1  0.412  0.291  0.751  7.2  0.173  iversal01
# 4  16.9   6.8  10.8  2.3  0.4  0.444  0.366  0.757  8.1  0.188   kiddja01
#
#    Year
# 0  1999
# 1  1999
# 2  1999
# 3  1999
# 4  1999

# %%
data_mvp.isna().sum()
# Out:
# Rank       0
# Player     0
# Age        0
# Tm         0
# First      0
# Pts Won    0
# Pts Max    0
# Share      0
# G          0
# MP         0
# PTS        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# FG%        0
# 3P%        9
# FT%        0
# WS         0
# WS/48      0
# Other      0
# Year       0
# dtype: int64

# %% [markdown]
# Players info from API.

# %%
import pandas as pd
from nba_api.stats.static import players

nba_players = players.get_players()
nba_players_df = pd.DataFrame(nba_players)

# %%
# nba_players_df

# %% [markdown]
# We search for the id of the player for our MVP list in the API database.

# %%
data_mvp_2 = data_mvp.merge(nba_players_df[['full_name', 'id']], left_on='Player', right_on='full_name', how='left')

# %%
data_mvp_2.isna().sum()
# Out:
# Rank          0
# Player        0
# Age           0
# Tm            0
# First         0
# Pts Won       0
# Pts Max       0
# Share         0
# G             0
# MP            0
# PTS           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# FG%           0
# 3P%           9
# FT%           0
# WS            0
# WS/48         0
# Other         0
# Year          0
# full_name    16
# id           16
# dtype: int64

# %%
data_mvp_2[data_mvp_2['id'].isna()]
# Out:
#     Rank           Player  Age   Tm  First  Pts Won  Pts Max  Share   G    MP  \
# 19   16T      Steve Smith   29  ATL    0.0      1.0     1180  0.001  36  36.5
# 71   16T  Peja Stojaković   24  SAC    0.0      1.0     1260  0.001  71  37.3
# 88     4  Peja Stojaković   26  SAC    1.0    281.0     1230  0.228  81  40.3
# 154   10    Manu Ginóbili   30  SAS    0.0      9.0     1260  0.007  74  31.1
# 184   11    Manu Ginóbili   32  SAS    0.0      3.0     1230  0.002  75  28.7
# 196    8    Manu Ginóbili   33  SAS    0.0     20.0     1210  0.017  80  30.3
# 248   16     Goran Dragić   27  PHO    0.0      3.0     1250  0.002  76  35.1
# 299    4     Nikola Jokić   23  DEN    0.0    212.0     1010  0.210  80  31.3
# 310    4      Luka Dončić   20  DAL    0.0    200.0     1010  0.198  61  33.6
# 315    9     Nikola Jokić   24  DEN    0.0     18.0     1010  0.018  73  32.0
# 319    1     Nikola Jokić   25  DEN   91.0    971.0     1010  0.961  72  34.6
# ...

# %%
data_mvp_2['Player'] = data_mvp_2['Player'].str.replace('ć', 'c').str.replace('ó', 'o').str.replace('č', 'c')

# %%
data_mvp['Player'] = data_mvp['Player'].str.replace('ć', 'c').str.replace('ó', 'o').str.replace('č', 'c')

# %%
data_mvp_2 = data_mvp.merge(nba_players_df[['full_name', 'id']], left_on='Player', right_on='full_name', how='left')

# %%
data_mvp_2[data_mvp_2['id'].isna()]
# Out:
#    Rank       Player  Age   Tm  First  Pts Won  Pts Max  Share   G    MP  \
# 19  16T  Steve Smith   29  ATL    0.0      1.0     1180  0.001  36  36.5
#
#      PTS  TRB  AST  STL  BLK    FG%    3P%    FT%   WS  WS/48      Other  \
# 19  18.7  4.2  3.3  1.0  0.3  0.402  0.338  0.849  4.4  0.162  smithst01
#
#     Year full_name  id
# 19  1999       NaN NaN

# %%
data_mvp.loc[19, 'Player'] = 'Steven Smith'

# %%
data_mvp_2 = data_mvp.merge(nba_players_df[['full_name', 'id']], left_on='Player', right_on='full_name', how='left')

# %%
data_mvp_2.isna().sum()
# Out:
# Rank         0
# Player       0
# Age          0
# Tm           0
# First        0
# Pts Won      0
# Pts Max      0
# Share        0
# G            0
# MP           0
# PTS          0
# TRB          0
# AST          0
# STL          0
# BLK          0
# FG%          0
# 3P%          9
# FT%          0
# WS           0
# WS/48        0
# Other        0
# Year         0
# full_name    0
# id           0
# dtype: int64

# %%
data_mvp_2.drop('full_name', axis=1, inplace=True)

# %% [markdown]
# We only need the player, the share of votes and the year.

# %%
mvp_shares = data_mvp_2[['Year', 'id', 'Player', 'Share']]

# %%
# mvp_shares

# %%
mvp_shares.dtypes
# Out:
# Year        int64
# id          int64
# Player     object
# Share     float64
# dtype: object

# %% [markdown]
# Concat tot_stats y mvp_shares.

# %%
def calculate_year_mvp(season):
    year_parts = season.split('-')
    first_year = int(year_parts[0]) + 1
    return first_year

tot_stats['YEAR_MVP'] = tot_stats['SEASON'].apply(calculate_year_mvp)

# %%
# tot_stats['YEAR_MVP'].unique()

# %%
# tot_stats

# %%
mvp_shares['PK_3'] = mvp_shares['id'].astype(str) + '_' + mvp_shares['Year'].astype(str)
# Out:
# C:\Users\dcast\AppData\Local\Temp\ipykernel_17836\2904909158.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mvp_shares['PK_3'] = mvp_shares['id'].astype(str) + '_' + mvp_shares['Year'].astype(str)

# %%
tot_stats['PK_3'] = tot_stats['PLAYER_ID'].astype(str) + '_' + tot_stats['YEAR_MVP'].astype(str)

# %%
data = tot_stats.merge(mvp_shares[['PK_3', 'Share']], on='PK_3', how='left')

# %%
print(len(tot_stats))
len(mvp_shares)
# Out:
# 11966
# 360

# %%
data.isna().sum()
# Out:
# PLAYER_ID                0
# PLAYER_NAME              0
# NICKNAME                 0
# TEAM_ID                  0
# TEAM_ABBREVIATION        0
#                      ...
# CONF_RANK                0
# DIV_RANK                 0
# YEAR_MVP                 0
# PK_3                     0
# Share                11607
# Length: 74, dtype: int64

# %%
test = mvp_shares.merge(tot_stats, on='PK_3', how='left')

# %%
test[test['PLAYER_ID'].isna()]
# Out:
#     Year      id        Player  Share         PK_3  PLAYER_ID PLAYER_NAME  \
# 20  1999  200848  Steven Smith  0.001  200848_1999        NaN         NaN
#
#    NICKNAME  TEAM_ID TEAM_ABBREVIATION  AGE  GP   W   L  W_PCT  MIN  FGM  FGA  \
# 20      NaN      NaN               NaN  NaN NaN NaN NaN    NaN  NaN  NaN  NaN
#
#     FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  TOV  \
# 20     NaN   NaN   NaN      NaN  NaN  NaN     NaN   NaN   NaN  NaN  NaN  NaN
#
#     STL  BLK  BLKA  PF  PFD  PTS  PLUS_MINUS  NBA_FANTASY_PTS  DD2  TD3  \
# 20  NaN  NaN   NaN NaN  NaN  NaN         NaN              NaN  NaN  NaN
#
#     WNBA_FANTASY_PTS SEASON   PK  E_OFF_RATING  OFF_RATING  \
# 20               NaN    NaN  NaN           NaN         NaN
#
#     sp_work_OFF_RATING  E_DEF_RATING  DEF_RATING  sp_work_DEF_RATING  \
# 20                 NaN           NaN         NaN                 NaN
#
#     E_NET_RATING  NET_RATING  sp_work_NET_RATING  AST_PCT  AST_TO  AST_RATIO  \
# ...

# %% [markdown]
# We are unable only to match one value, which has a very low share, so we will treat this row as having no share.

# %%
data.isna().sum()
# Out:
# PLAYER_ID                0
# PLAYER_NAME              0
# NICKNAME                 0
# TEAM_ID                  0
# TEAM_ABBREVIATION        0
#                      ...
# CONF_RANK                0
# DIV_RANK                 0
# YEAR_MVP                 0
# PK_3                     0
# Share                11607
# Length: 74, dtype: int64

# %%
data.isna().sum().sum()
# Out:
# 11607

# %% [markdown]
# We will fill those nans (players who were not voted for the mvp) with a zero in the share column.

# %%
data.dtypes
# Out:
# PLAYER_ID              int64
# PLAYER_NAME           object
# NICKNAME              object
# TEAM_ID                int64
# TEAM_ABBREVIATION     object
#                       ...
# CONF_RANK              int64
# DIV_RANK               int64
# YEAR_MVP               int64
# PK_3                  object
# Share                float64
# Length: 74, dtype: object

# %%
data['Share'].fillna(0, inplace=True)

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
# data.to_csv('data.csv', index=False)
