# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('ev_fg_per_game.csv')

# %%
# data

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data['YEAR_1'] = data['YEAR'].str.split('-').str[0]

# %%
# data

# %%
data
# Out:
#        YEAR  FGM_PER_GAME  FGA_PER_GAME  FG2M_PER_GAME  FG2A_PER_GAME  \
# 0   1998-99     34.168966     78.196552      29.714483      65.033793
# 1   1999-00     36.831034     82.096552      31.992431      68.379310
# 2   2000-01     35.682759     80.603448      30.841463      66.891085
# 3   2001-02     36.172414     81.268966      30.954163      66.521867
# 4   2002-03     35.710345     80.782759      30.587468      66.104710
# 5   2003-04     35.006897     79.817241      29.828848      64.890664
# 6   2004-05     35.943333     80.336667      30.348780      64.584553
# 7   2005-06     35.836667     78.990000      30.113821      63.008943
# 8   2006-07     36.526667     79.710000      30.460976      62.764634
# 9   2007-08     37.260000     81.510000      30.709350      63.397154
# 10  2008-09     37.113333     80.916667      30.470732      62.793089
# 11  2009-10     37.696667     81.693333      31.263415      63.563821
# ...
